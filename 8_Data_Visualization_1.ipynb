# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('housing.csv')

# %%
df.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e31fae3ec0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e31fb1c440>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e31e6f2c00>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1e31fb1ca40>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1e31fb1cd40>,
# ...
#  'means': []}

# %%
sns.pairplot(df)

# %%
plt.plot(df['RM'])

# %%
plt.bar(df['RM'], df['PTRATIO'], width=0.3)
# Out:
# <BarContainer object of 489 artists>

# %%
plt.barh(df['RM'], df['MEDV'])
# Out:
# <BarContainer object of 489 artists>

# %%
plt.hist(df['RM'])
# Out:
# (array([  2.,   4.,  10.,  25., 122., 178.,  86.,  44.,  11.,   7.]),
#  array([3.561 , 4.0447, 4.5284, 5.0121, 5.4958, 5.9795, 6.4632, 6.9469,
#         7.4306, 7.9143, 8.398 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['RM'], df['MEDV'])

# %%
aa = np.array([11,12,454,777])
# aa = [12, 111, 44, 1344]
plt.pie(aa)
# aa.mean()
# Out:
# ([<matplotlib.patches.Wedge at 0x1e329b76ed0>,
# ...
#  [Text(1.0995823377212235, 0.030309776830746465, ''),
#   Text(1.09601193167088, 0.09358336195642025, ''),
#   Text(0.34410938235223515, 1.0447912389454477, ''),
#   Text(-0.4037067959767225, -1.023240354404677, '')])

# %%
plt.boxplot(df['RM'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e329b58620>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e329b595b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e329b82120>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e329b58f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e329b58c80>],
#  'means': []}

# %%
plt.hist(df['RM'])
# Out:
# (array([  2.,   4.,  10.,  25., 122., 178.,  86.,  44.,  11.,   7.]),
#  array([3.561 , 4.0447, 4.5284, 5.0121, 5.4958, 5.9795, 6.4632, 6.9469,
#         7.4306, 7.9143, 8.398 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(aa, labels=['one', 'too', 'thrie', 'foor'], wedges)
# Out:
#   Cell In[35], line 1
#     plt.pie(aa, labels=['one', 'too', 'thrie', 'foor'], wedges)
#                                                               ^
# SyntaxError: positional argument follows keyword argument

# %%
plt.violinplot(df['RM'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1e32a1ab6b0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1e329a28ad0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1e32a1fd1f0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1e32a154d70>}
