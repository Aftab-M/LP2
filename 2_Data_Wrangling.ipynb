# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('derma.csv')

# %%
df.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
df.shape
# Out:
# (366, 35)

# %%
df.size
# Out:
# 12810

# %%
df['age'].head(20)
# Out:
# 0     55
# 1      8
# 2     26
# 3     40
# 4     45
# 5     41
# 6     18
# 7     57
# 8     22
# 9     30
# 10    20
# 11    21
# 12    22
# 13    10
# 14    65
# 15    40
# 16    30
# 17    38
# 18    23
# 19    17
# Name: age, dtype: object

# %%
df.dtypes
# Out:
# erythema                                int64
# scaling                                 int64
# definite_borders                        int64
# itching                                 int64
# koebner_phenomenon                      int64
# polygonal_papules                       int64
# follicular_papules                      int64
# oral_mucosal_involvement                int64
# knee_and_elbow_involvement              int64
# scalp_involvement                       int64
# family_history                          int64
# melanin_incontinence                    int64
# eosinophils_infiltrate                  int64
# PNL_infiltrate                          int64
# fibrosis_papillary_dermis               int64
# exocytosis                              int64
# acanthosis                              int64
# hyperkeratosis                          int64
# parakeratosis                           int64
# clubbing_rete_ridges                    int64
# ...

# %%
import matplotlib.pyplot as plt


plt.boxplot(df['itching'])

plt.show()

# %%
np.random.seed(0)

# Number of rows and columns
num_rows = 40
num_cols = 5

# Generating random data
data = {
    'A': np.random.normal(loc=50, scale=10, size=num_rows),  # Normal distribution
    'B': np.random.uniform(low=0, high=100, size=num_rows),  # Uniform distribution
    'C': np.random.gamma(shape=2, scale=10, size=num_rows),  # Gamma distribution
    'D': np.random.exponential(scale=10, size=num_rows),  # Exponential distribution
    'E': np.random.poisson(lam=5, size=num_rows),  # Poisson distribution
}

# Introducing null values
for col in data:
    null_indices = np.random.choice(num_rows, size=5, replace=False)
    data[col][null_indices] = 0

df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  40.000000  40.000000  40.000000  40.000000  40.000000
# mean   46.898936  35.020914  19.674213   8.690281   4.025000
# std    20.892475  29.531802  13.904237   9.778353   2.655304
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    41.374818  11.455699   9.162556   2.040160   2.000000
# 50%    53.233710  28.947358  19.604451   5.388813   4.000000
# 75%    60.346485  53.408640  28.301970  12.213399   5.250000
# max    72.697546  98.837384  54.271350  46.396527  11.000000

# %%
df.head(30)
# Out:
#             A          B          C          D   E
# 0   67.640523  31.542835  27.962283  27.213482   6
# 1   54.001572  36.371077  18.387900   9.518297   2
# 2   59.787380  57.019677  22.419156   7.670797   0
# 3   72.408932  43.860151   9.296888   0.000000   4
# 4   68.675580  98.837384  12.959415  13.097854   4
# 5   40.227221  10.204481  17.402324   3.738865   7
# 6   59.500884  20.887676   5.696102   5.078651   4
# 7   48.486428  16.130952  31.210966   0.000000   4
# 8    0.000000  65.310833  23.430116   2.060320   0
# 9   54.105985  25.329160   0.000000  28.890756  10
# 10   0.000000  46.631077  36.986288  13.453474   6
# 11  64.542735   0.000000  14.450086   6.742446   4
# 12  57.610377  15.896958  11.984712   2.580128   7
# 13   0.000000   0.000000  37.953687   2.935077   3
# 14  54.438632   0.000000  21.703644   0.597810   0
# 15  53.336743  13.818295   0.000000   5.698976   2
# 16  64.940791  19.658236  18.359370   0.000000   6
# ...

# %%
import matplotlib.pyplot as plt

plt.boxplot(df['D'])
plt.show()

# %%
df = pd.read_csv('sperf.csv')

# %%
df.isnull().sum()
# Out:
# STUDENT ID                                                           0
# Student Age                                                          0
# Sex                                                                  0
# Graduated high-school type                                           0
# Scholarship type                                                     0
# Additional work                                                      0
# Regular artistic or sports activity                                  0
# Do you have a partner                                                0
# Total salary if available                                            0
# Transportation to the university                                     0
# Accommodation type in Cyprus                                         0
# Mother’s education                                                   0
# Father’s education                                                   0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      STUDENT ID  Student Age  Sex  Graduated high-school type  \
# 0      STUDENT1            2    2                           3
# 1      STUDENT2            2    2                           3
# 2      STUDENT3            2    2                           2
# 3      STUDENT4            1    1                           1
# 4      STUDENT5            2    2                           1
# ..          ...          ...  ...                         ...
# 140  STUDENT141            2    1                           2
# 141  STUDENT142            1    1                           2
# 142  STUDENT143            1    1                           1
# 143  STUDENT144            2    1                           2
# 144  STUDENT145            1    1                           1
#
#      Scholarship type  Additional work  Regular artistic or sports activity  \
# 0                   3                1                                    2
# ...

# %%
df.columns
# Out:
# Index(['STUDENT ID', 'Student Age', 'Sex', 'Graduated high-school type',
#        'Scholarship type', 'Additional work',
#        'Regular artistic or sports activity', 'Do you have a partner',
#        'Total salary if available', 'Transportation to the university',
#        'Accommodation type in Cyprus', 'Mother’s education',
#        'Father’s education ', 'Number of sisters/brothers', 'Parental status',
#        'Mother’s occupation', 'Father’s occupation', 'Weekly study hours',
#        'Reading frequency', 'Reading frequency.1',
#        'Attendance to the seminars/conferences related to the department',
#        'Impact of your projects/activities on your success',
#        'Attendance to classes', 'Preparation to midterm exams 1',
#        'Preparation to midterm exams 2', 'Taking notes in classes',
#        'Listening in classes',
#        'Discussion improves my interest and success in the course',
#        'Flip-classroom',
# ...

# %%
# df.boxplot()

plt.boxplot(df['Reading frequency.1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1aab03524b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1aab0352ae0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1aab0352210>],
#  'medians': [<matplotlib.lines.Line2D at 0x1aab0352f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1aab0353290>],
#  'means': []}

# %%
data = {
    'name': ['abc', 'def', 'ghi', 'jkl', 'mno', 'pqr', 'stu', 'vwx', 'yz', 'ab', 'cd', 'ef', 'gh', 'ij'], 
    'age': [20, 12, np.nan, np.nan, 20, 11, 9, 1, 90, 44, 32, np.nan, 43, 44]
}

# %%
df = pd.DataFrame(data)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    name   age
# 0   abc  20.0
# 1   def  12.0
# 2   ghi   NaN
# 3   jkl   NaN
# 4   mno  20.0
# 5   pqr  11.0
# 6   stu   9.0
# 7   vwx   1.0
# 8    yz  90.0
# 9    ab  44.0
# 10   cd  32.0
# 11   ef   NaN
# 12   gh  43.0
# 13   ij  44.0>

# %%
df
# Out:
#    name   age
# 0   abc  20.0
# 1   def  12.0
# 2   ghi   NaN
# 3   jkl   NaN
# 4   mno  20.0
# 5   pqr  11.0
# 6   stu   9.0
# 7   vwx   1.0
# 8    yz  90.0
# 9    ab  44.0
# 10   cd  32.0
# 11   ef   NaN
# 12   gh  43.0
# 13   ij  44.0

# %%
df.isna().sum()
# Out:
# name    0
# age     3
# dtype: int64

# %%
age_mean = df['age'].mean()

df.fillna(age_mean, inplace=True)
df['age']
# Out:
# 0     20.000000
# 1     12.000000
# 2     29.636364
# 3     29.636364
# 4     20.000000
# 5     11.000000
# 6      9.000000
# 7      1.000000
# 8     90.000000
# 9     44.000000
# 10    32.000000
# 11    29.636364
# 12    43.000000
# 13    44.000000
# Name: age, dtype: float64

# %%
outliers = []
import seaborn as sns

def detect_outliers(data, threshold):
    for i in df['age']:
        mean = df['age'].mean()
        std = df['age'].std()
        z_score = (i - mean) / std
        if np.abs(z_score) > threshold:
            print('Value beyond threshold : ',i,' with z_score : ',z_score)
            outliers.append(i)
    return outliers
print(detect_outliers(df,1))
# Out:
# Value beyond threshold :  1.0  with z_score :  -1.2976840869304551
# Value beyond threshold :  90.0  with z_score :  2.73543566260896
# [1.0, 90.0]

# %%
def outlier_limits(col):
    q3 = df['age'].quantile(0.75)
    q1 = df['age'].quantile(0.25)
    
    iqr = q3 - q1
    print(iqr," is the IQR")
    
    ul = q3 + 1.5 * iqr
    ll = q1 - 1.5 * iqr
    return ul, ll

for ele in df:
    ul, ll = outlier_limits(df[ele])
    print('Element : ',ele," ll : ",ll,' ul : ',ul)
    df[ele] = np.where( df[ele] > ul, ul, np.where( df[ele] < ll, ll, df[ele] ))
# Out:
# 26.25  is the IQR
# Element :  name  ll :  -25.375  ul :  79.625
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[91], line 15
#      13 ul, ll = outlier_limits(df[ele])
#      14 print('Element : ',ele," ll : ",ll,' ul : ',ul)
# ---> 15 df[ele] = np.where( df[ele] > ul, ul, np.where( df[ele] < ll, ll, df[ele] ))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# ...

# %%
sns.pairplot(df)

plt.show()

# %%
newds = pd.DataFrame()
newds['math log'] = np.log10(df['age'])

newds['age'] = df['age']
