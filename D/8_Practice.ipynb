# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train_and_test2.csv')

# %%
df.isna().sum()
# Out:
# Passengerid    0
# Age            0
# Fare           0
# Sex            0
# sibsp          0
# zero           0
# zero.1         0
# zero.2         0
# zero.3         0
# zero.4         0
# zero.5         0
# zero.6         0
# Parch          0
# zero.7         0
# zero.8         0
# zero.9         0
# zero.10        0
# zero.11        0
# zero.12        0
# zero.13        0
# zero.14        0
# Pclass         0
# zero.15        0
# zero.16        0
# Embarked       2
# zero.17        0
# zero.18        0
# 2urvived       0
# dtype: int64

# %%
df['Embarked'].head()
# Out:
# 0    2.0
# 1    0.0
# 2    2.0
# 3    2.0
# 4    2.0
# Name: Embarked, dtype: float64

# %%
df['Embarked'].isna().sum()
# Out:
# 2

# %%
df['Embarked'].describe()
# Out:
# count    1307.000000
# mean        1.492731
# std         0.814626
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         2.000000
# Name: Embarked, dtype: float64

# %%
df['Embarked'] = df['Embarked'].fillna(50)
df['Embarked']
# Out:
# 0       2.0
# 1       0.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 1304    2.0
# 1305    0.0
# 1306    2.0
# 1307    2.0
# 1308    0.0
# Name: Embarked, Length: 1309, dtype: float64

# %%
df['Embarked'].describe()
# Out:
# count    1309.000000
# mean        1.566845
# std         2.062739
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max        50.000000
# Name: Embarked, dtype: float64

# %%
cols = ['Fare', 'Embarked']
newds = df.filter(['Fare', 'Sex', 'Embarked'], axis=1)
# newds.boxplot()

news = df[['Fare', 'Embarked', 'Age', 'Sex']]

# newds['Fare']

# %%
sns.pairplot(news)

# %%
sns.heatmap(news)
# Out:
# <Axes: >

# %%
sns.jointplot( x='Fare', y='Age', data=df, kind='scatter' )

# %%
bins = [0, 20, 50, 90]
news['agecat'] = pd.cut( news['Age'], bins=bins, labels=['Young', 'Adult', 'Old'] )
# Out:
# C:\Users\Aftab\AppData\Local\Temp\ipykernel_10952\3158301148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['agecat'] = pd.cut( news['Age'], bins=bins, labels=['Young', 'Adult', 'Old'] )

# %%
news['agecat']
# Out:
# 0       Adult
# 1       Adult
# 2       Adult
# 3       Adult
# 4       Adult
#         ...
# 1304    Adult
# 1305    Adult
# 1306    Adult
# 1307    Adult
# 1308    Adult
# Name: agecat, Length: 1309, dtype: category
# Categories (3, object): ['Young' < 'Adult' < 'Old']

# %%
sns.boxplot(x='agecat', y='Fare', data=news)
# Out:
# <Axes: xlabel='agecat', ylabel='Fare'>

# %%
sns.violinplot( x='agecat', y='Fare', data=news )
# Out:
# <Axes: xlabel='agecat', ylabel='Fare'>

# %%
sns.countplot(x='agecat', data=news)
# Out:
# <Axes: xlabel='agecat', ylabel='count'>

# %%
news.hist()
plt.show()

# %%
df['Fare'].hist( bins=10 )
# Out:
# <Axes: >

# %%
df['Fare'].describe()
# Out:
# count    1309.000000
# mean       33.281086
# std        51.741500
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %%
sns.histplot(data=news['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(data=df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot( data=df['Fare'].head(50), kde=True )
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
mydf['2urvived']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: 2urvived, Length: 1309, dtype: int64

# %%
mydf = df[['Sex', 'Age', '2urvived', 'Fare', 'Passengerid']]

bins = [0, 20, 60, 90]
mydf['agecat'] = pd.cut(mydf['Age'], bins=bins, labels=['Young', 'Adult', 'Old'])

sns.histplot(x='agecat', y='Passengerid', hue='2urvived', data=mydf)
# Out:
# C:\Users\Aftab\AppData\Local\Temp\ipykernel_10952\3993519917.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf['agecat'] = pd.cut(mydf['Age'], bins=bins, labels=['Young', 'Adult', 'Old'])
# <Axes: xlabel='agecat', ylabel='Passengerid'>

# %%
sns.boxplot(x='Sex', y='Age', hue='2urvived', data=mydf)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
